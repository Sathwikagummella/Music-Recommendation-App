# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\sathw\Downloads\ex.csv")
df
# Out:
#                                Song-Name  \
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# 3                                 Mungda
# 4                               Tere Bin
# ...                                  ...
# 2415              Jana Tumhare Pyar Mein
# 2416             Tum Jaise Bigde Babu Se
# 2417              O Yaad Nahi Bhool Gaya
# 2418   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2419  Mummy Aur Daddy Mein Ladai Ho Gayi
#
#                                         Singer/Artists  \
# 0                  Kumar Sanu, Mika Singh, Neha Kakkar
# 1                             Neha Kakkar, Tony Kakkar
# 2                                        Ranveer Singh
# 3                Jyotica Tangri, Shaan, Subhro Ganguly
# 4     Asees Kaur, Rahat Fateh Ali Khan, Tanishk Bagchi
# ...                                                ...
# 2415                                            Mukesh
# 2416                                   Lata Mangeshkar
# 2417                    Lata Mangeshkar, Suresh Wadkar
# 2418                                       Jagjit Kaur
# 2419                                       Asha Bhosle
#
#                        Genre                Album/Movie User-Rating
# 0             BollywoodDance                     Simmba      8.8/10
# 1     BollywoodDanceRomantic                Luka Chuppi      9.0/10
# 2             BollywoodDance                  Gully Boy      9.7/10
# 3             BollywoodDance              Total Dhamaal      9.1/10
# 4          BollywoodRomantic                     Simmba      9.2/10
# ...                      ...                        ...         ...
# 2415          BollywoodDance                    Sasural      6.2/10
# 2416          BollywoodDance  Jab Pyar Kisi Se Hota Hai      7.2/10
# 2417          BollywoodDance                      Lamhe      7.5/10
# 2418          BollywoodDance          Shola Aur Shabnam      6.5/10
# 2419          BollywoodDance          Shola Aur Shabnam      6.6/10
#
# [2420 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# Song-Name          0
# Singer/Artists    10
# Genre              0
# Album/Movie        3
# User-Rating        0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Song-Name         0
# Singer/Artists    0
# Genre             0
# Album/Movie       0
# User-Rating       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 16

# %%
df=df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (2391, 5)

# %%
df.head()
# Out:
#           Song-Name                                    Singer/Artists  \
# 0       Aankh Marey               Kumar Sanu, Mika Singh, Neha Kakkar
# 1         Coca Cola                          Neha Kakkar, Tony Kakkar
# 2  Apna Time Aayega                                     Ranveer Singh
# 3            Mungda             Jyotica Tangri, Shaan, Subhro Ganguly
# 4          Tere Bin  Asees Kaur, Rahat Fateh Ali Khan, Tanishk Bagchi
#
#                     Genre    Album/Movie User-Rating
# 0          BollywoodDance         Simmba      8.8/10
# 1  BollywoodDanceRomantic    Luka Chuppi      9.0/10
# 2          BollywoodDance      Gully Boy      9.7/10
# 3          BollywoodDance  Total Dhamaal      9.1/10
# 4       BollywoodRomantic         Simmba      9.2/10

# %%
df['User-Rating']
# Out:
# 0       8.8/10
# 1       9.0/10
# 2       9.7/10
# 3       9.1/10
# 4       9.2/10
#          ...
# 2415    6.2/10
# 2416    7.2/10
# 2417    7.5/10
# 2418    6.5/10
# 2419    6.6/10
# Name: User-Rating, Length: 2391, dtype: object

# %%
l=[]
for i in df['User-Rating']:
    l.append(i[1:3])
l
# Out:
# ['.8',
#  '.0',
#  '.7',
#  '.1',
#  '.2',
#  '.1',
#  '.2',
#  '.5',
#  '.2',
#  '.6',
#  '.8',
#  '.4',
#  '.1',
#  '.2',
#  '.0',
#  '.7',
#  '.1',
#  '.0',
#  '.0',
#  '.1',
#  '.2',
#  '.2',
#  '.5',
#  '.6',
#  '.1',
#  '.0',
#  '.0',
#  '.2',
#  '.5',
#  '.4',
#  '.7',
#  '.3',
#  '.3',
#  '.5',
#  '.1',
#  '.0',
#  '.0',
#  '.1',
#  '.4',
#  '.4',
#  '.8',
#  '.2',
#  '.2',
#  '.6',
#  '.6',
#  '.0',
#  '.1',
#  '.5',
#  '.5',
#  '.5',
#  '.7',
#  '.9',
#  '.6',
#  '.5',
#  '.1',
#  '.7',
#  '.6',
#  '.3',
#  '.7',
#  '.9',
#  '.0',
#  '.0',
#  '.3',
#  '.3',
#  '.1',
#  '.0',
#  '.7',
#  '.2',
#  '.1',
#  '.0',
#  '.9',
#  '.5',
#  '.5',
#  '.7',
#  '.0',
#  '.1',
#  '.1',
#  '.5',
#  '.1',
#  '.6',
#  '.4',
#  '.0',
#  '.0',
#  '.6',
#  '.3',
#  '.0',
#  '.2',
#  '.3',
#  '.1',
#  '.6',
#  '.5',
#  '.5',
#  '.0',
#  '.4',
#  '.2',
#  '.6',
#  '.3',
#  '.7',
#  '.2',
#  '.3',
#  '.7',
#  '.0',
#  '.5',
#  '.4',
#  '.0',
#  '.2',
#  '.0',
#  '.4',
#  '.4',
#  '.1',
#  '.3',
#  '.2',
#  '.1',
#  '.0',
#  '.8',
#  '.9',
#  '.8',
#  '.9',
#  '.2',
#  '.7',
#  '.2',
#  '.4',
#  '.0',
#  '.9',
#  '.9',
#  '.7',
#  '.9',
#  '.6',
#  '.5',
#  '.7',
#  '.4',
#  '.5',
#  '.3',
#  '.3',
#  '.2',
#  '.3',
#  '.9',
#  '.7',
#  '.1',
#  '.6',
#  '.4',
#  '.6',
#  '.6',
#  '.1',
#  '.2',
#  '.6',
#  '.6',
#  '.8',
#  '.7',
#  '.4',
#  '.0',
#  '.1',
#  '.6',
#  '.3',
#  '.4',
#  '.2',
#  '.5',
#  '.6',
#  '.9',
#  '.4',
#  '.7',
#  '.4',
#  '.4',
#  '.5',
#  '.3',
#  '.1',
#  '.5',
#  '.4',
#  '.6',
#  '.4',
#  '.3',
#  '.1',
#  '.2',
#  '.0',
#  '.2',
#  '.7',
#  '.5',
#  '.7',
#  '.3',
#  '.3',
#  '.7',
#  '.0',
#  '.2',
#  '.2',
#  '.8',
#  '.1',
#  '.3',
#  '.2',
#  '.0',
#  '.2',
#  '.5',
#  '.6',
#  '.3',
#  '.7',
#  '.5',
#  '.9',
#  '.6',
#  '.7',
#  '.4',
#  '.2',
#  '.2',
#  '.1',
#  '.1',
#  '.7',
#  '.9',
#  '.4',
#  '.4',
#  '.0',
#  '.1',
#  '.4',
#  '.6',
#  '.3',
#  '.5',
#  '.5',
#  '.2',
#  '.6',
#  '.9',
#  '.6',
#  '.4',
#  '.4',
#  '.6',
#  '.6',
#  '.9',
#  '.6',
#  '.2',
#  '.7',
#  '.9',
#  '.7',
#  '.6',
#  '.2',
#  '.2',
#  '.2',
#  '.4',
#  '.0',
#  '.4',
#  '.7',
#  '.8',
#  '.6',
#  '.4',
#  '.9',
#  '.4',
#  '.0',
#  '.5',
#  '.5',
#  '.3',
#  '.7',
#  '.0',
#  '.2',
#  '.4',
#  '.1',
#  '.8',
#  '.1',
#  '.2',
#  '.2',
#  '.4',
#  '.0',
#  '.7',
#  '.4',
#  '.1',
#  '.8',
#  '.1',
#  '.1',
#  '.7',
#  '.7',
#  '.4',
#  '.5',
#  '.8',
#  '.9',
#  '.3',
#  '.5',
#  '.3',
#  '.2',
#  '.5',
#  '.9',
#  '.1',
#  '.3',
#  '.4',
#  '.3',
#  '.6',
#  '.8',
#  '.6',
#  '.1',
#  '.8',
#  '.8',
#  '.4',
#  '.4',
#  '.4',
#  '.1',
#  '.0',
#  '.5',
#  '.5',
#  '.3',
#  '.5',
#  '.9',
#  '.0',
#  '.6',
#  '.4',
#  '.5',
#  '.0',
#  '.5',
#  '.5',
#  '.8',
#  '.4',
#  '.3',
#  '.4',
#  '.1',
#  '.6',
#  '.7',
#  '.8',
#  '.1',
#  '.1',
#  '.1',
#  '.0',
#  '.3',
#  '.7',
#  '.2',
#  '.3',
#  '.3',
#  '.4',
#  '.0',
#  '.3',
#  '.9',
#  '.0',
#  '.4',
#  '.1',
#  '.4',
#  '.3',
#  '.6',
#  '.1',
#  '.0',
#  '.9',
#  '.5',
#  '.2',
#  '.2',
#  '.2',
#  '.4',
#  '.3',
#  '.4',
#  '.3',
#  '.3',
#  '.1',
#  '.3',
#  '.2',
#  '.2',
#  '.6',
#  '.4',
#  '.3',
#  '.1',
#  '.3',
#  '.6',
#  '.1',
#  '.8',
#  '.8',
#  '.1',
#  '.3',
#  '.5',
#  '.3',
#  '.8',
#  '.8',
#  '.2',
#  '.7',
#  '.4',
#  '.3',
#  '.1',
#  '.7',
#  '.6',
#  '.1',
#  '.9',
#  '.0',
#  '.2',
#  '.1',
#  '.1',
#  '.1',
#  '.1',
#  '.1',
#  '.1',
#  '.8',
#  '.8',
#  '.4',
#  '.7',
#  '.4',
#  '.4',
#  '.3',
#  '.1',
#  '.7',
#  '.9',
#  '.3',
#  '.4',
#  '.6',
#  '.4',
#  '.7',
#  '.0',
#  '.1',
#  '.1',
#  '.1',
#  '.4',
#  '.4',
#  '.5',
#  '.2',
#  '.3',
#  '.9',
#  '.4',
#  '.0',
#  '.5',
#  '.7',
#  '.2',
#  '.7',
#  '.0',
#  '.4',
#  '.2',
#  '.5',
#  '.7',
#  '.2',
#  '.4',
#  '.9',
#  '.2',
#  '.9',
#  '.6',
#  '.6',
#  '.7',
#  '.4',
#  '.3',
#  '.5',
#  '.3',
#  '.2',
#  '.8',
#  '.9',
#  '.3',
#  '.9',
#  '.4',
#  '.4',
#  '.2',
#  '.2',
#  '.0',
#  '.3',
#  '.9',
#  '.6',
#  '.2',
#  '.9',
#  '.6',
#  '.2',
#  '.2',
#  '.5',
#  '.3',
#  '.6',
#  '.6',
#  '.4',
#  '.1',
#  '.2',
#  '.8',
#  '.1',
#  '.2',
#  '.4',
#  '.6',
#  '.2',
#  '.5',
#  '.4',
#  '.3',
#  '.9',
#  '.2',
#  '.1',
#  '.2',
#  '.1',
#  '.5',
#  '.4',
#  '.8',
#  '.3',
#  '.4',
#  '.0',
#  '.7',
#  '.7',
#  '.5',
#  '.3',
#  '.3',
#  '.2',
#  '.5',
#  '.3',
#  '.3',
#  '.2',
#  '.2',
#  '.2',
#  '.8',
#  '.8',
#  '.4',
#  '.7',
#  '.0',
#  '.4',
#  '.7',
#  '.4',
#  '.7',
#  '.5',
#  '.7',
#  '.3',
#  '.0',
#  '.0',
#  '.2',
#  '.6',
#  '.6',
#  '.1',
#  '.3',
#  '.9',
#  '.7',
#  '.3',
#  '.0',
#  '.8',
#  '.0',
#  '.3',
#  '.3',
#  '.3',
#  '.2',
#  '.2',
#  '.0',
#  '.4',
#  '.9',
#  '.0',
#  '.1',
#  '.1',
#  '.9',
#  '.4',
#  '.7',
#  '.5',
#  '.2',
#  '.4',
#  '.4',
#  '.1',
#  '.2',
#  '.5',
#  '.8',
#  '.7',
#  '.0',
#  '.2',
#  '.7',
#  '.6',
#  '.3',
#  '.0',
#  '.4',
#  '.6',
#  '.8',
#  '.0',
#  '.1',
#  '.3',
#  '.6',
#  '.0',
#  '.9',
#  '.4',
#  '.5',
#  '.9',
#  '.9',
#  '.1',
#  '.9',
#  '.8',
#  '.4',
#  '.2',
#  '.4',
#  '.9',
#  '.6',
#  '.1',
#  '.4',
#  '.5',
#  '.2',
#  '.7',
#  '.5',
#  '.2',
#  '.7',
#  '.4',
#  '.3',
#  '.5',
#  '.4',
#  '.1',
#  '.6',
#  '.5',
#  '.4',
#  '.1',
#  '.2',
#  '.6',
#  '.7',
#  '.9',
#  '.7',
#  '.7',
#  '.1',
#  '.2',
#  '.9',
#  '.9',
#  '.6',
#  '.0',
#  '.3',
#  '.6',
#  '.3',
#  '.3',
#  '.3',
#  '.5',
#  '.9',
#  '.8',
#  '.8',
#  '.6',
#  '.2',
#  '.7',
#  '.6',
#  '.7',
#  '.2',
#  '.2',
#  '.2',
#  '.3',
#  '.3',
#  '.5',
#  '.5',
#  '.9',
#  '.1',
#  '.7',
#  '.6',
#  '.3',
#  '.6',
#  '.7',
#  '.7',
#  '.9',
#  '.2',
#  '.5',
#  '.3',
#  '.3',
#  '.4',
#  '.3',
#  '.9',
#  '.2',
#  '.5',
#  '.6',
#  '.6',
#  '.7',
#  '.0',
#  '.4',
#  '.5',
#  '.2',
#  '.3',
#  '.8',
#  '.4',
#  '.5',
#  '.5',
#  '.1',
#  '.7',
#  '.4',
#  '.1',
#  '.9',
#  '.3',
#  '.1',
#  '.4',
#  '.5',
#  '.1',
#  '.6',
#  '.0',
#  '.5',
#  '.2',
#  '.3',
#  '.0',
#  '.6',
#  '.5',
#  '.4',
#  '.3',
#  '.2',
#  '.3',
#  '.5',
#  '.1',
#  '.2',
#  '.4',
#  '.5',
#  '.4',
#  '.6',
#  '.6',
#  '.2',
#  '.2',
#  '.2',
#  '.2',
#  '.9',
#  '.6',
#  '.3',
#  '.0',
#  '.6',
#  '.0',
#  '.2',
#  '.3',
#  '.4',
#  '.7',
#  '.6',
#  '.3',
#  '.9',
#  '.3',
#  '.5',
#  '.5',
#  '.0',
#  '.5',
#  '.2',
#  '.8',
#  '.6',
#  '.7',
#  '.3',
#  '.3',
#  '.4',
#  '.1',
#  '.3',
#  '.6',
#  '.6',
#  '.9',
#  '.5',
#  '.5',
#  '.8',
#  '.0',
#  '.6',
#  '.6',
#  '.6',
#  '.7',
#  '.5',
#  '.5',
#  '.6',
#  '.2',
#  '.1',
#  '.3',
#  '.6',
#  '.3',
#  '.5',
#  '.1',
#  '.2',
#  '.6',
#  '.6',
#  '.8',
#  '.8',
#  '.1',
#  '.0',
#  '.3',
#  '.1',
#  '.7',
#  '.0',
#  '.1',
#  '.2',
#  '.6',
#  '.4',
#  '.0',
#  '.7',
#  '.4',
#  '.3',
#  '.2',
#  '.1',
#  '.9',
#  '.3',
#  '.7',
#  '.4',
#  '.9',
#  '.3',
#  '.8',
#  '.0',
#  '.1',
#  '.3',
#  '.2',
#  '.5',
#  '.8',
#  '.7',
#  '.4',
#  '.2',
#  '.0',
#  '.9',
#  '.6',
#  '.1',
#  '.0',
#  '.6',
#  '.4',
#  '.3',
#  '.5',
#  '.6',
#  '.1',
#  '.3',
#  '.5',
#  '.2',
#  '.0',
#  '.4',
#  '.4',
#  '.5',
#  '.5',
#  '.5',
#  '.8',
#  '.3',
#  '.5',
#  '.1',
#  '.7',
#  '.1',
#  '.2',
#  '.3',
#  '.3',
#  '.7',
#  '.5',
#  '.6',
#  '.1',
#  '.0',
#  '.3',
#  '.1',
#  '.2',
#  '.6',
#  '.5',
#  '.4',
#  '.3',
#  '.9',
#  '.9',
#  '.3',
#  '.1',
#  '.9',
#  '.7',
#  '.8',
#  '.1',
#  '.1',
#  '.4',
#  '.4',
#  '.7',
#  '.1',
#  '.4',
#  '.3',
#  '.2',
#  '.6',
#  '.2',
#  '.3',
#  '.1',
#  '.9',
#  '.0',
#  '.2',
#  '.8',
#  '.2',
#  '.4',
#  '.4',
#  '.4',
#  '.2',
#  '.3',
#  '.3',
#  '.1',
#  '.4',
#  '.3',
#  '.4',
#  '.8',
#  '.0',
#  '.6',
#  '.3',
#  '.3',
#  '.4',
#  '.9',
#  '.4',
#  '.3',
#  '.3',
#  '.7',
#  '.5',
#  '.6',
#  '.4',
#  '.2',
#  '.3',
#  '.5',
#  '.3',
#  '.5',
#  '.3',
#  '.3',
#  '.2',
#  '.2',
#  '.5',
#  '.7',
#  '.6',
#  '.2',
#  '.3',
#  '.3',
#  '.6',
#  '.0',
#  '.6',
#  '.7',
#  '.1',
#  '.1',
#  '.6',
#  '.5',
#  '.4',
#  '.2',
#  '.8',
#  '.5',
#  '.4',
#  '.0',
#  '.1',
#  '.4',
#  '.2',
#  '.4',
#  '.8',
#  '.5',
#  '.1',
#  '.4',
#  '.2',
#  '.0',
#  '.3',
#  '.6',
#  '.9',
#  '.5',
#  '.5',
#  '.6',
#  '.1',
#  '.1',
#  '.7',
#  '.7',
#  '.7',
#  '.3',
#  '.1',
#  '.2',
#  '.4',
#  '.3',
#  '.0',
#  '.2',
#  '.6',
#  '.7',
#  '.6',
#  '.6',
#  '.4',
#  '.3',
#  '.8',
#  '.0',
#  '.1',
#  '.0',
#  '.2',
#  '.8',
#  '.5',
#  '.8',
#  '.4',
#  '.4',
#  '.3',
#  '.2',
#  '.2',
#  '.2',
#  '.4',
#  '.4',
#  '.6',
#  '.6',
#  '.6',
#  '.2',
#  '.5',
#  '.4',
#  '.3',
#  '.5',
#  '.4',
#  '.5',
#  '.3',
#  '.2',
#  '.9',
#  '.4',
#  '.0',
#  '.3',
#  '.8',
#  '.3',
#  '.6',
#  '.0',
#  '.0',
#  '.4',
#  '.6',
#  '.4',
#  '.5',
#  '.8',
#  '.4',
#  '.3',
#  '.4',
#  '.2',
#  '.9',
#  '.2',
#  '.4',
#  '.6',
#  '.3',
#  '.6',
#  '.2',
#  '.1',
#  '.2',
#  '.5',
#  '.3',
#  '.5',
#  '.2',
#  '.4',
#  '.5',
#  '.3',
#  '.2',
#  '.6',
#  '.7',
#  '.1',
#  '.2',
#  '.6',
#  '.2',
#  '.2',
#  '.9',
#  '.6',
#  '.7',
#  '.3',
#  '.4',
#  '.2',
#  '.6',
#  '.5',
#  '.8',
#  '.5',
#  '.3',
#  '.8',
#  '.4',
#  '.9',
#  '.6',
#  '.2',
#  '.2',
#  '.3',
#  '.4',
#  '.2',
#  '.5',
#  '.3',
#  ...]

# %%
df.loc[:,'User-Rating'] = l
df
# Out:
#                                Song-Name  \
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# 3                                 Mungda
# 4                               Tere Bin
# ...                                  ...
# 2415              Jana Tumhare Pyar Mein
# 2416             Tum Jaise Bigde Babu Se
# 2417              O Yaad Nahi Bhool Gaya
# 2418   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2419  Mummy Aur Daddy Mein Ladai Ho Gayi
#
#                                  Singer/Artists                   Genre  \
# 0                KumarSanu MikaSingh NehaKakkar          BollywoodDance
# 1                         NehaKakkar TonyKakkar  BollywoodDanceRomantic
# 2                                  RanveerSingh          BollywoodDance
# 3             JyoticaTangri Shaan SubhroGanguly          BollywoodDance
# 4     AseesKaur RahatFatehAliKhan TanishkBagchi       BollywoodRomantic
# ...                                         ...                     ...
# 2415                                     Mukesh          BollywoodDance
# 2416                             LataMangeshkar          BollywoodDance
# 2417                LataMangeshkar SureshWadkar          BollywoodDance
# 2418                                 JagjitKaur          BollywoodDance
# 2419                                 AshaBhosle          BollywoodDance
#
#                Album/Movie User-Rating  \
# 0                   Simmba          .8
# 1               LukaChuppi          .0
# 2                 GullyBoy          .7
# 3             TotalDhamaal          .1
# 4                   Simmba          .2
# ...                    ...         ...
# 2415               Sasural          .2
# 2416  JabPyarKisiSeHotaHai          .2
# 2417                 Lamhe          .5
# 2418       SholaAurShabnam          .5
# 2419       SholaAurShabnam          .6
#
#                                                    tags
# 0     KumarSanu MikaSingh NehaKakkar BollywoodDance ...
# 1     NehaKakkar TonyKakkar BollywoodDanceRomantic L...
# 2               RanveerSingh BollywoodDance GullyBoy .7
# 3     JyoticaTangri Shaan SubhroGanguly BollywoodDan...
# 4     AseesKaur RahatFatehAliKhan TanishkBagchi Boll...
# ...                                                 ...
# 2415                   Mukesh BollywoodDance Sasural .2
# 2416  LataMangeshkar BollywoodDance JabPyarKisiSeHot...
# 2417  LataMangeshkar SureshWadkar BollywoodDance Lam...
# 2418       JagjitKaur BollywoodDance SholaAurShabnam .5
# 2419       AshaBhosle BollywoodDance SholaAurShabnam .6
#
# [2391 rows x 6 columns]

# %%
df['Album/Movie']=df['Album/Movie'].str.replace(' ','')
df['Singer/Artists']=df['Singer/Artists'].str.replace(' ','')
df
# Out:
# C:\Users\sathw\AppData\Local\Temp\ipykernel_23240\3143610327.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Album/Movie']=df['Album/Movie'].str.replace(' ','')
# C:\Users\sathw\AppData\Local\Temp\ipykernel_23240\3143610327.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Singer/Artists']=df['Singer/Artists'].str.replace(' ','')
#                                Song-Name  \
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# 3                                 Mungda
# 4                               Tere Bin
# ...                                  ...
# 2415              Jana Tumhare Pyar Mein
# 2416             Tum Jaise Bigde Babu Se
# 2417              O Yaad Nahi Bhool Gaya
# 2418   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2419  Mummy Aur Daddy Mein Ladai Ho Gayi
#
#                                  Singer/Artists                   Genre  \
# 0                KumarSanu,MikaSingh,NehaKakkar          BollywoodDance
# 1                         NehaKakkar,TonyKakkar  BollywoodDanceRomantic
# 2                                  RanveerSingh          BollywoodDance
# 3             JyoticaTangri,Shaan,SubhroGanguly          BollywoodDance
# 4     AseesKaur,RahatFatehAliKhan,TanishkBagchi       BollywoodRomantic
# ...                                         ...                     ...
# 2415                                     Mukesh          BollywoodDance
# 2416                             LataMangeshkar          BollywoodDance
# 2417                LataMangeshkar,SureshWadkar          BollywoodDance
# 2418                                 JagjitKaur          BollywoodDance
# 2419                                 AshaBhosle          BollywoodDance
#
#                Album/Movie User-Rating
# 0                   Simmba          .8
# 1               LukaChuppi          .0
# 2                 GullyBoy          .7
# 3             TotalDhamaal          .1
# 4                   Simmba          .2
# ...                    ...         ...
# 2415               Sasural          .2
# 2416  JabPyarKisiSeHotaHai          .2
# 2417                 Lamhe          .5
# 2418       SholaAurShabnam          .5
# 2419       SholaAurShabnam          .6
#
# [2391 rows x 5 columns]

# %%
df['Singer/Artists']=df['Singer/Artists'].str.replace(',',' ')
df
# Out:
# C:\Users\sathw\AppData\Local\Temp\ipykernel_23240\1991446236.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Singer/Artists']=df['Singer/Artists'].str.replace(',',' ')
#                                Song-Name  \
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# 3                                 Mungda
# 4                               Tere Bin
# ...                                  ...
# 2415              Jana Tumhare Pyar Mein
# 2416             Tum Jaise Bigde Babu Se
# 2417              O Yaad Nahi Bhool Gaya
# 2418   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2419  Mummy Aur Daddy Mein Ladai Ho Gayi
#
#                                  Singer/Artists                   Genre  \
# 0                KumarSanu MikaSingh NehaKakkar          BollywoodDance
# 1                         NehaKakkar TonyKakkar  BollywoodDanceRomantic
# 2                                  RanveerSingh          BollywoodDance
# 3             JyoticaTangri Shaan SubhroGanguly          BollywoodDance
# 4     AseesKaur RahatFatehAliKhan TanishkBagchi       BollywoodRomantic
# ...                                         ...                     ...
# 2415                                     Mukesh          BollywoodDance
# 2416                             LataMangeshkar          BollywoodDance
# 2417                LataMangeshkar SureshWadkar          BollywoodDance
# 2418                                 JagjitKaur          BollywoodDance
# 2419                                 AshaBhosle          BollywoodDance
#
#                Album/Movie User-Rating
# 0                   Simmba          .8
# 1               LukaChuppi          .0
# 2                 GullyBoy          .7
# 3             TotalDhamaal          .1
# 4                   Simmba          .2
# ...                    ...         ...
# 2415               Sasural          .2
# 2416  JabPyarKisiSeHotaHai          .2
# 2417                 Lamhe          .5
# 2418       SholaAurShabnam          .5
# 2419       SholaAurShabnam          .6
#
# [2391 rows x 5 columns]

# %%
df['Album/Movie']=df['Album/Movie'].str.replace(' ','')
df['Singer/Artists']=df['Singer/Artists'].str.replace(' ','')
df
# Out:
# C:\Users\sathw\AppData\Local\Temp\ipykernel_23240\3143610327.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Album/Movie']=df['Album/Movie'].str.replace(' ','')
# C:\Users\sathw\AppData\Local\Temp\ipykernel_23240\3143610327.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Singer/Artists']=df['Singer/Artists'].str.replace(' ','')
#                                Song-Name  \
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# 3                                 Mungda
# 4                               Tere Bin
# ...                                  ...
# 2415              Jana Tumhare Pyar Mein
# 2416             Tum Jaise Bigde Babu Se
# 2417              O Yaad Nahi Bhool Gaya
# 2418   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2419  Mummy Aur Daddy Mein Ladai Ho Gayi
#
#                                Singer/Artists                   Genre  \
# 0                KumarSanuMikaSinghNehaKakkar          BollywoodDance
# 1                        NehaKakkarTonyKakkar  BollywoodDanceRomantic
# 2                                RanveerSingh          BollywoodDance
# 3             JyoticaTangriShaanSubhroGanguly          BollywoodDance
# 4     AseesKaurRahatFatehAliKhanTanishkBagchi       BollywoodRomantic
# ...                                       ...                     ...
# 2415                                   Mukesh          BollywoodDance
# 2416                           LataMangeshkar          BollywoodDance
# 2417               LataMangeshkarSureshWadkar          BollywoodDance
# 2418                               JagjitKaur          BollywoodDance
# 2419                               AshaBhosle          BollywoodDance
#
#                Album/Movie User-Rating  \
# 0                   Simmba          .8
# 1               LukaChuppi          .0
# 2                 GullyBoy          .7
# 3             TotalDhamaal          .1
# 4                   Simmba          .2
# ...                    ...         ...
# 2415               Sasural          .2
# 2416  JabPyarKisiSeHotaHai          .2
# 2417                 Lamhe          .5
# 2418       SholaAurShabnam          .5
# 2419       SholaAurShabnam          .6
#
#                                                    tags
# 0     KumarSanu MikaSingh NehaKakkar BollywoodDance ...
# 1     NehaKakkar TonyKakkar BollywoodDanceRomantic L...
# 2               RanveerSingh BollywoodDance GullyBoy .7
# 3     JyoticaTangri Shaan SubhroGanguly BollywoodDan...
# 4     AseesKaur RahatFatehAliKhan TanishkBagchi Boll...
# ...                                                 ...
# 2415                   Mukesh BollywoodDance Sasural .2
# 2416  LataMangeshkar BollywoodDance JabPyarKisiSeHot...
# 2417  LataMangeshkar SureshWadkar BollywoodDance Lam...
# 2418       JagjitKaur BollywoodDance SholaAurShabnam .5
# 2419       AshaBhosle BollywoodDance SholaAurShabnam .6
#
# [2391 rows x 6 columns]

# %%
df['Singer/Artists']=df['Singer/Artists'].str.replace(',',' ')
df
# Out:
# C:\Users\sathw\AppData\Local\Temp\ipykernel_23240\1991446236.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Singer/Artists']=df['Singer/Artists'].str.replace(',',' ')
#                                Song-Name  \
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# 3                                 Mungda
# 4                               Tere Bin
# ...                                  ...
# 2415              Jana Tumhare Pyar Mein
# 2416             Tum Jaise Bigde Babu Se
# 2417              O Yaad Nahi Bhool Gaya
# 2418   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2419  Mummy Aur Daddy Mein Ladai Ho Gayi
#
#                                Singer/Artists                   Genre  \
# 0                KumarSanuMikaSinghNehaKakkar          BollywoodDance
# 1                        NehaKakkarTonyKakkar  BollywoodDanceRomantic
# 2                                RanveerSingh          BollywoodDance
# 3             JyoticaTangriShaanSubhroGanguly          BollywoodDance
# 4     AseesKaurRahatFatehAliKhanTanishkBagchi       BollywoodRomantic
# ...                                       ...                     ...
# 2415                                   Mukesh          BollywoodDance
# 2416                           LataMangeshkar          BollywoodDance
# 2417               LataMangeshkarSureshWadkar          BollywoodDance
# 2418                               JagjitKaur          BollywoodDance
# 2419                               AshaBhosle          BollywoodDance
#
#                Album/Movie User-Rating  \
# 0                   Simmba          .8
# 1               LukaChuppi          .0
# 2                 GullyBoy          .7
# 3             TotalDhamaal          .1
# 4                   Simmba          .2
# ...                    ...         ...
# 2415               Sasural          .2
# 2416  JabPyarKisiSeHotaHai          .2
# 2417                 Lamhe          .5
# 2418       SholaAurShabnam          .5
# 2419       SholaAurShabnam          .6
#
#                                                    tags
# 0     KumarSanu MikaSingh NehaKakkar BollywoodDance ...
# 1     NehaKakkar TonyKakkar BollywoodDanceRomantic L...
# 2               RanveerSingh BollywoodDance GullyBoy .7
# 3     JyoticaTangri Shaan SubhroGanguly BollywoodDan...
# 4     AseesKaur RahatFatehAliKhan TanishkBagchi Boll...
# ...                                                 ...
# 2415                   Mukesh BollywoodDance Sasural .2
# 2416  LataMangeshkar BollywoodDance JabPyarKisiSeHot...
# 2417  LataMangeshkar SureshWadkar BollywoodDance Lam...
# 2418       JagjitKaur BollywoodDance SholaAurShabnam .5
# 2419       AshaBhosle BollywoodDance SholaAurShabnam .6
#
# [2391 rows x 6 columns]

# %%
df['tags']=df['Singer/Artists']+' '+df['Genre']+' '+df['Album/Movie']+' '+df['User-Rating']
df['tags'][0]
df
# Out:
# C:\Users\sathw\AppData\Local\Temp\ipykernel_23240\3673787969.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags']=df['Singer/Artists']+' '+df['Genre']+' '+df['Album/Movie']+' '+df['User-Rating']
#                                Song-Name  \
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# 3                                 Mungda
# 4                               Tere Bin
# ...                                  ...
# 2415              Jana Tumhare Pyar Mein
# 2416             Tum Jaise Bigde Babu Se
# 2417              O Yaad Nahi Bhool Gaya
# 2418   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2419  Mummy Aur Daddy Mein Ladai Ho Gayi
#
#                                Singer/Artists                   Genre  \
# 0                KumarSanuMikaSinghNehaKakkar          BollywoodDance
# 1                        NehaKakkarTonyKakkar  BollywoodDanceRomantic
# 2                                RanveerSingh          BollywoodDance
# 3             JyoticaTangriShaanSubhroGanguly          BollywoodDance
# 4     AseesKaurRahatFatehAliKhanTanishkBagchi       BollywoodRomantic
# ...                                       ...                     ...
# 2415                                   Mukesh          BollywoodDance
# 2416                           LataMangeshkar          BollywoodDance
# 2417               LataMangeshkarSureshWadkar          BollywoodDance
# 2418                               JagjitKaur          BollywoodDance
# 2419                               AshaBhosle          BollywoodDance
#
#                Album/Movie User-Rating  \
# 0                   Simmba          .8
# 1               LukaChuppi          .0
# 2                 GullyBoy          .7
# 3             TotalDhamaal          .1
# 4                   Simmba          .2
# ...                    ...         ...
# 2415               Sasural          .2
# 2416  JabPyarKisiSeHotaHai          .2
# 2417                 Lamhe          .5
# 2418       SholaAurShabnam          .5
# 2419       SholaAurShabnam          .6
#
#                                                    tags
# 0     KumarSanuMikaSinghNehaKakkar BollywoodDance Si...
# 1     NehaKakkarTonyKakkar BollywoodDanceRomantic Lu...
# 2               RanveerSingh BollywoodDance GullyBoy .7
# 3     JyoticaTangriShaanSubhroGanguly BollywoodDance...
# 4     AseesKaurRahatFatehAliKhanTanishkBagchi Bollyw...
# ...                                                 ...
# 2415                   Mukesh BollywoodDance Sasural .2
# 2416  LataMangeshkar BollywoodDance JabPyarKisiSeHot...
# 2417  LataMangeshkarSureshWadkar BollywoodDance Lamh...
# 2418       JagjitKaur BollywoodDance SholaAurShabnam .5
# 2419       AshaBhosle BollywoodDance SholaAurShabnam .6
#
# [2391 rows x 6 columns]

# %%
new_df=df[['Song-Name','tags']]
new_df
# Out:
#                                Song-Name  \
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# 3                                 Mungda
# 4                               Tere Bin
# ...                                  ...
# 2415              Jana Tumhare Pyar Mein
# 2416             Tum Jaise Bigde Babu Se
# 2417              O Yaad Nahi Bhool Gaya
# 2418   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2419  Mummy Aur Daddy Mein Ladai Ho Gayi
#
#                                                    tags
# 0     KumarSanuMikaSinghNehaKakkar BollywoodDance Si...
# 1     NehaKakkarTonyKakkar BollywoodDanceRomantic Lu...
# 2               RanveerSingh BollywoodDance GullyBoy .7
# 3     JyoticaTangriShaanSubhroGanguly BollywoodDance...
# 4     AseesKaurRahatFatehAliKhanTanishkBagchi Bollyw...
# ...                                                 ...
# 2415                   Mukesh BollywoodDance Sasural .2
# 2416  LataMangeshkar BollywoodDance JabPyarKisiSeHot...
# 2417  LataMangeshkarSureshWadkar BollywoodDance Lamh...
# 2418       JagjitKaur BollywoodDance SholaAurShabnam .5
# 2419       AshaBhosle BollywoodDance SholaAurShabnam .6
#
# [2391 rows x 2 columns]

# %%
new_df['tags']=new_df['tags'].apply(lambda x:x.lower())
new_df
# Out:
# C:\Users\sathw\AppData\Local\Temp\ipykernel_23240\2565169282.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags']=new_df['tags'].apply(lambda x:x.lower())
#                                Song-Name  \
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# 3                                 Mungda
# 4                               Tere Bin
# ...                                  ...
# 2415              Jana Tumhare Pyar Mein
# 2416             Tum Jaise Bigde Babu Se
# 2417              O Yaad Nahi Bhool Gaya
# 2418   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2419  Mummy Aur Daddy Mein Ladai Ho Gayi
#
#                                                    tags
# 0     kumarsanumikasinghnehakakkar bollywooddance si...
# 1     nehakakkartonykakkar bollywooddanceromantic lu...
# 2               ranveersingh bollywooddance gullyboy .7
# 3     jyoticatangrishaansubhroganguly bollywooddance...
# 4     aseeskaurrahatfatehalikhantanishkbagchi bollyw...
# ...                                                 ...
# 2415                   mukesh bollywooddance sasural .2
# 2416  latamangeshkar bollywooddance jabpyarkisisehot...
# 2417  latamangeshkarsureshwadkar bollywooddance lamh...
# 2418       jagjitkaur bollywooddance sholaaurshabnam .5
# 2419       ashabhosle bollywooddance sholaaurshabnam .6
#
# [2391 rows x 2 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer(max_features=2000)

# %%
new_df.shape
new_df['tags'].shape
# Out:
# (2391,)

# %% [raw]
# vectors=cv.fit_transform(new_df['tags']).toarray()
# # vectors.shape
# print(cv.get_feature_names_out().shape)  #  1697 : lấy được 1697 từ phổ biến
# print(cv.get_feature_names_out())  #  1697 : lấy được 1697 từ phổ biến
# print(vectors.shape) # 2391, 1697
#
#
# # Xây dựng từ vựng: Giả sử tất cả các từ đều nằm trong top 2000 từ phổ biến nhất, từ vựng sẽ là:
# #['activities', 'fun', 'is', 'love', 'programming'].
#
# # Biến đổi văn bản thành vector số:
#
# # "I love programming." -> [0, 0, 0, 1, 1]
# # "Programming is fun." -> [0, 1, 1, 0, 1]
# # "I love fun activities." -> [1, 1, 0, 1, 0]
#
# # Hỉu nuôn
# vectors[0,0:10]

# %%
vectors.shape
# Out:
# (2391, 1697)

# %%
from sklearn.metrics.pairwise import cosine_similarity
similarity=cosine_similarity(vectors)
print(similarity)
print(similarity.shape)
# Out:
# [[1.         0.2236068  0.25819889 ... 0.2236068  0.25819889 0.25819889]
#  [0.2236068  1.         0.         ... 0.         0.         0.        ]
#  [0.25819889 0.         1.         ... 0.28867513 0.33333333 0.33333333]
#  ...
#  (1475, 0.25819888974716115),
#  (1474, 0.0),
#  (1473, 0.25819888974716115),
#  (1472, 0.25819888974716115),
#  (1471, 0.0),
#  (1470, 0.22360679774997896),
#  (1469, 0.0),
#  (1468, 0.0),
#  (1467, 0.25819888974716115),
#  (1466, 0.0),
#  (1465, 0.0),
#  (1464, 0.0),
#  (1463, 0.22360679774997896),
#  (1462, 0.25819888974716115),
#  (1461, 0.0),
#  (1460, 0.25819888974716115),
#  (1459, 0.0),
#  (1458, 0.0),
#  (1457, 0.0),
#  (1456, 0.0),
#  (1455, 0.0),
#  (1454, 0.19999999999999998),
#  (1453, 0.0),
#  (1452, 0.22360679774997896),
#  (1451, 0.0),
#  (1450, 0.19999999999999998),
#  (1449, 0.0),
#  (1448, 0.22360679774997896),
#  (1447, 0.0),
#  (1446, 0.0),
#  (1445, 0.19999999999999998),
#  (1444, 0.0),
#  (1443, 0.0),
#  (1442, 0.22360679774997896),
#  (1441, 0.0),
#  (1440, 0.18257418583505539),
#  (1439, 0.25819888974716115),
#  (1438, 0.25819888974716115),
#  (1437, 0.22360679774997896),
#  (1436, 0.19999999999999998),
#  (1435, 0.0),
#  (1434, 0.0),
#  (1433, 0.25819888974716115),
#  (1432, 0.22360679774997896),
#  (1431, 0.22360679774997896),
#  (1430, 0.0),
#  (1429, 0.22360679774997896),
#  (1428, 0.22360679774997896),
#  (1427, 0.22360679774997896),
#  (1426, 0.0),
#  (1425, 0.0),
#  (1424, 0.0),
#  (1423, 0.0),
#  (1422, 0.0),
#  (1421, 0.0),
#  (1420, 0.22360679774997896),
#  (1419, 0.22360679774997896),
#  (1418, 0.22360679774997896),
#  (1417, 0.25819888974716115),
#  (1416, 0.0),
#  (1415, 0.22360679774997896),
#  (1414, 0.22360679774997896),
#  (1413, 0.0),
#  (1412, 0.0),
#  (1411, 0.0),
#  (1410, 0.22360679774997896),
#  (1409, 0.22360679774997896),
#  (1408, 0.0),
#  (1407, 0.0),
#  (1406, 0.22360679774997896),
#  (1405, 0.25819888974716115),
#  (1404, 0.0),
#  (1403, 0.22360679774997896),
#  (1402, 0.22360679774997896),
#  (1401, 0.22360679774997896),
#  (1400, 0.25819888974716115),
#  (1399, 0.25819888974716115),
#  (1398, 0.25819888974716115),
#  (1397, 0.0),
#  (1396, 0.25819888974716115),
#  (1395, 0.2981423969999719),
#  (1394, 0.22360679774997896),
#  (1393, 0.0),
#  (1392, 0.19999999999999998),
#  (1391, 0.19999999999999998),
#  ...]

# %%
new_df.rename(columns={'Song-Name':'title'},inplace=True)
# Out:
# C:\Users\sathw\AppData\Local\Temp\ipykernel_23240\1892644493.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.rename(columns={'Song-Name':'title'},inplace=True)

# %%
def recommend(music):
    music_index=new_df[new_df['title']==music].index[0]
    distances=similarity[music_index]
    music_list=sorted(list(enumerate(distances)),reverse=True,key=lambda x:x[1])[1:6]
    for i in music_list:
        print(new_df.iloc[i[0]].title)

# %%
recommend('Proper Patola')
# Out:
# Abhi Toh Party Shuru Hui Hai
# Bhare Bazaar
# Tareefan Remix
# Pant Mein Gun
# Pee Paa Pee Paa

# %%
df.head(50)
# Out:
#                           Song-Name  \
# 0                       Aankh Marey
# 1                         Coca Cola
# 2                  Apna Time Aayega
# 3                            Mungda
# 4                          Tere Bin
# 5                         Gali Gali
# 6                     Chamma Chamma
# 7                   Mere Gully Mein
# 8                          Kamariya
# 9   Ek Ladki Ko Dekha Toh Aisa Laga
# 10                   Swag Se Swagat
# 11                  Poster Lagwa Do
# 12                      Daaru Wargi
# 13                           Dilbar
# 14                    Proper Patola
# 15                            Doori
# 16                 Dil Diyan Gallan
# 17                     Husn Parcham
# 18                  Bom Diggy Diggy
# 19                       Issaqbaazi
# 20                     Mere Naam Tu
# 21    High Rated Gabru – Nawabzaade
# 22                    Dekhte Dekhte
# 23                          Zingaat
# 24                         Tareefan
# 25            Mile Ho Tum (Reprise)
# 26                        Dil Chori
# 27                 Tere Naal Nachna
# 28                 Dil Meri Na Sune
# 29               Dhadak Title Track
# 30                          Heeriye
# 31                          Chogada
# 32              Gud Naal Ishq Mitha
# 33                       Paniyon Sa
# 34                    Milegi Milegi
# 35                      Morni Banke
# 36                     Bhare Bazaar
# 37                        Khalibali
# 38              Aao Kabhi Haveli Pe
# 39                Badri Ki Dulhania
# 40                       Cheez Badi
# 41                          Dholida
# 42                       Sweetheart
# 43                        Namo Namo
# 44                        Qaafirana
# 45                         Tu Hi Re
# 46                Chhote Chhote Peg
# 47                 Galti Se Mistake
# 48                    Phir Mulaaqat
# 49                     Kala Chashma
#
#                                   Singer/Artists                   Genre  \
# 0                   KumarSanuMikaSinghNehaKakkar          BollywoodDance
# 1                           NehaKakkarTonyKakkar  BollywoodDanceRomantic
# 2                                   RanveerSingh          BollywoodDance
# 3                JyoticaTangriShaanSubhroGanguly          BollywoodDance
# 4        AseesKaurRahatFatehAliKhanTanishkBagchi       BollywoodRomantic
# 5                                     NehaKakkar          BollywoodDance
# 6                         ArunIkkaNehaKakkarRomy          BollywoodDance
# 7                                   RanveerSingh          BollywoodDance
# 8                                   DarshanRaval          BollywoodDance
# 9                        DarshanRavalRochakKohli       BollywoodRomantic
# 10                       NehaBhasinVishalDadlani          BollywoodDance
# 11                        MikaSinghSunandaSharma          BollywoodDance
# 12                                  GuruRandhawa          BollywoodDance
# 13                DhvaniBhanushaliIkkaNehaKakkar          BollywoodDance
# 14                AasthaGillBadshahDiljitDosanjh          BollywoodDance
# 15                                  RanveerSingh          BollywoodDance
# 16                                     AtifAslam       BollywoodRomantic
# 17                       BhoomiTrivediRajaKumari          BollywoodDance
# 18                         JasminWaliaZackKnight          BollywoodDance
# 19                     DivyaKumarSukhwinderSingh          BollywoodDance
# 20                               AbhayJodhpurkar       BollywoodRomantic
# 21                                  GuruRandhawa          BollywoodDance
# 22                                     AtifAslam       BollywoodRomantic
# 23                                      AjayAtul          BollywoodDance
# 24                                       Badshah               Bollywood
# 25                          NehaKakkarTonyKakkar       BollywoodRomantic
# 26                 IshersSimarKaurYoYoHoneySingh          BollywoodDance
# 27                          BadshahSunandaSharma          BollywoodDance
# 28                                     AtifAslam       BollywoodRomantic
# 29                     AjayGogavaleShreyaGhoshal       BollywoodRomantic
# 30                   DeepMoneyMeetBrosNehaBhasin  BollywoodDanceRomantic
# 31                         AseesKaurDarshanRaval          BollywoodDance
# 32                       HarshdeepKaurNavrajHans          BollywoodDance
# 33                           AtifAslamTulsiKumar       BollywoodRomantic
# 34                                     MikaSingh          BollywoodDance
# 35                        GuruRandhawaNehaKakkar          BollywoodDance
# 36            BPraakBadshahPayalDevVishalDadlani          BollywoodDance
# 37                                  ShivamPathak          BollywoodDance
# 38        BadshahJigarNikhitaGandhiSachinSanghvi          BollywoodDance
# 39             DevNegiIkkaMonaliThakurNehaKakkar          BollywoodDance
# 40                         NehaKakkarUditNarayan          BollywoodDance
# 41  NehaKakkarPalakMuchchalRajaHassanUditNarayan          BollywoodDance
# 42                                       DevNegi          BollywoodDance
# 43                                   AmitTrivedi     BollywoodDevotional
# 44                      ArijitSinghNikhitaGandhi       BollywoodRomantic
# 45                    ArmaanMalikShashaaTirupati          BollywoodDance
# 46            NavrajHansNehaKakkarYoYoHoneySingh          BollywoodDance
# 47                         AmitMishraArijitSingh          BollywoodDance
# 48                                 JubinNautiyal       BollywoodRomantic
# 49                    AmarArshiBadshahNehaKakkar          BollywoodDance
#
#                   Album/Movie User-Rating  \
# 0                      Simmba          .8
# 1                  LukaChuppi          .0
# 2                    GullyBoy          .7
# 3                TotalDhamaal          .1
# 4                      Simmba          .2
# 5                         KGF          .1
# 6                FraudSaiyaan          .2
# 7                    GullyBoy          .5
# 8                      Mitron          .2
# 9   EkLadkiKoDekhaTohAisaLaga          .6
# 10              TigerZindaHai          .8
# 11                 LukaChuppi          .4
# 12                 CheatIndia          .1
# 13            SatyamevaJayate          .2
# 14             NamasteEngland          .0
# 15                   GullyBoy          .7
# 16              TigerZindaHai          .1
# 17                       Zero          .0
# 18         SonuKeTituKiSweety          .0
# 19                       Zero          .1
# 20                       Zero          .2
# 21                 Nawabzaade          .2
# 22         BattiGulMeterChalu          .5
# 23                     Dhadak          .6
# 24             VeereDiWedding          .1
# 25                      Fever          .0
# 26         SonuKeTituKiSweety          .0
# 27                 Nawabzaade          .2
# 28                     Genius          .5
# 29                     Dhadak          .4
# 30                      Race3          .7
# 31                  Loveratri          .3
# 32  EkLadkiKoDekhaTohAisaLaga          .3
# 33            SatyamevaJayate          .5
# 34                      Stree          .1
# 35                  BadhaaiHo          .0
# 36             NamasteEngland          .0
# 37                  Padmaavat          .1
# 38                      Stree          .4
# 39        BadrinathKiDulhania          .4
# 40                    Machine          .8
# 41                  Loveratri          .2
# 42                  Kedarnath          .2
# 43                  Kedarnath          .6
# 44                  Kedarnath          .6
# 45                          2          .0
# 46         SonuKeTituKiSweety          .1
# 47                JaggaJasoos          .5
# 48                 CheatIndia          .5
# 49              BaarBaarDekho          .5
#
#                                                  tags
# 0   KumarSanuMikaSinghNehaKakkar BollywoodDance Si...
# 1   NehaKakkarTonyKakkar BollywoodDanceRomantic Lu...
# 2             RanveerSingh BollywoodDance GullyBoy .7
# 3   JyoticaTangriShaanSubhroGanguly BollywoodDance...
# 4   AseesKaurRahatFatehAliKhanTanishkBagchi Bollyw...
# 5                    NehaKakkar BollywoodDance KGF .1
# 6   ArunIkkaNehaKakkarRomy BollywoodDance FraudSai...
# 7             RanveerSingh BollywoodDance GullyBoy .5
# 8               DarshanRaval BollywoodDance Mitron .2
# 9   DarshanRavalRochakKohli BollywoodRomantic EkLa...
# 10  NehaBhasinVishalDadlani BollywoodDance TigerZi...
# 11  MikaSinghSunandaSharma BollywoodDance LukaChup...
# 12          GuruRandhawa BollywoodDance CheatIndia .1
# 13  DhvaniBhanushaliIkkaNehaKakkar BollywoodDance ...
# 14  AasthaGillBadshahDiljitDosanjh BollywoodDance ...
# 15            RanveerSingh BollywoodDance GullyBoy .7
# 16       AtifAslam BollywoodRomantic TigerZindaHai .1
# 17     BhoomiTrivediRajaKumari BollywoodDance Zero .0
# 18  JasminWaliaZackKnight BollywoodDance SonuKeTit...
# 19   DivyaKumarSukhwinderSingh BollywoodDance Zero .1
# 20          AbhayJodhpurkar BollywoodRomantic Zero .2
# 21          GuruRandhawa BollywoodDance Nawabzaade .2
# 22  AtifAslam BollywoodRomantic BattiGulMeterChalu .5
# 23                  AjayAtul BollywoodDance Dhadak .6
# 24                Badshah Bollywood VeereDiWedding .1
# 25    NehaKakkarTonyKakkar BollywoodRomantic Fever .0
# 26  IshersSimarKaurYoYoHoneySingh BollywoodDance S...
# 27  BadshahSunandaSharma BollywoodDance Nawabzaade .2
# 28              AtifAslam BollywoodRomantic Genius .5
# 29  AjayGogavaleShreyaGhoshal BollywoodRomantic Dh...
# 30  DeepMoneyMeetBrosNehaBhasin BollywoodDanceRoma...
# 31  AseesKaurDarshanRaval BollywoodDance Loveratri .3
# 32  HarshdeepKaurNavrajHans BollywoodDance EkLadki...
# 33  AtifAslamTulsiKumar BollywoodRomantic Satyamev...
# 34                  MikaSingh BollywoodDance Stree .1
# 35  GuruRandhawaNehaKakkar BollywoodDance BadhaaiH...
# 36  BPraakBadshahPayalDevVishalDadlani BollywoodDa...
# 37           ShivamPathak BollywoodDance Padmaavat .1
# 38  BadshahJigarNikhitaGandhiSachinSanghvi Bollywo...
# 39  DevNegiIkkaMonaliThakurNehaKakkar BollywoodDan...
# 40    NehaKakkarUditNarayan BollywoodDance Machine .8
# 41  NehaKakkarPalakMuchchalRajaHassanUditNarayan B...
# 42                DevNegi BollywoodDance Kedarnath .2
# 43       AmitTrivedi BollywoodDevotional Kedarnath .6
# 44  ArijitSinghNikhitaGandhi BollywoodRomantic Ked...
# 45     ArmaanMalikShashaaTirupati BollywoodDance 2 .0
# 46  NavrajHansNehaKakkarYoYoHoneySingh BollywoodDa...
# 47  AmitMishraArijitSingh BollywoodDance JaggaJaso...
# 48      JubinNautiyal BollywoodRomantic CheatIndia .5
# 49  AmarArshiBadshahNehaKakkar BollywoodDance Baar...

# %%
import pickle
pickle.dump(new_df,open('musicrec.pkl','wb'))

# %%
pickle.dump(similarity,open('similarities.pkl','wb'))
